# %% [markdown]
# # Loading Necessary Datasets

# %%
# Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn.preprocessing import LabelEncoder, MinMaxScaler, StandardScaler, KBinsDiscretizer

# %% [markdown]
# # creating necessary methods

# %% [markdown]
# ## drop column method

# %%
def drop_unused_columns(df, columns):
    return df.drop(columns = columns , inplace = True)

# %% [markdown]
# ## Encoding Methods

# %% [markdown]
# #### LabelEncoding Method

# %%
def labelencoder(df, columns):
    le = LabelEncoder()
    for col in columns:
        df[col] = le.fit_transform(df[col])
    return df

# %% [markdown]
# #### One-Hot Encoder

# %%
def one_hot(df, columns):
    return pd.get_dummies(df, columns=columns)

# %% [markdown]
# ## Discretization Method

# %%
def k_bins_discretizer(df, columns, n_bins, encode, strategy):
    dis = KBinsDiscretizer(n_bins=n_bins, encode=encode, strategy=strategy)
    for col in columns:
        df[col] = dis.fit_transform(df[[col]])
        df = df.astype({col: 'int'})
    return df

# %% [markdown]
# # Normalization Method

# %%
def min_max_scaler(df, columns):
    scaler = MinMaxScaler()
    for col in columns:
        df[col] = scaler.fit_transform(df[col])
    df.columns = columns
    return df

# %% [markdown]
# # Exploring & Cleaning Columns

# %%
# Laoding Dataset 
df = pd.read_csv('https://raw.githubusercontent.com/PeterLOVANAS/Titanic-machine-learning-project/main/datasets/Titanic_dataset_com.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1310 entries, 0 to 1309
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   float64
#  1   pclass       1309 non-null   float64
#  2   survived     1309 non-null   float64
#  3   name         1309 non-null   object
#  4   sex          1309 non-null   object
#  5   age          1046 non-null   float64
#  6   sibsp        1309 non-null   float64
#  7   parch        1309 non-null   float64
#  8   ticket       1309 non-null   object
#  9   fare         1308 non-null   float64
#  10  cabin        295 non-null    object
#  11  embarked     1307 non-null   object
#  12  boat         486 non-null    object
#  13  body         121 non-null    float64
#  14  home.dest    745 non-null    object
# dtypes: float64(8), object(7)
# memory usage: 153.6+ KB

# %% [markdown]
# # Drop NaN: 'all'

# %%
df.dropna(how='all', inplace = True)

# %% [markdown]
# # age column

# %%
df_age_median = df.groupby(['sex', 'pclass'])['age'].median().reset_index()
# df_age_median = pd.DataFrame(df_age_median)
df_age_median
# Out:
#       sex  pclass   age
# 0  female     1.0  36.0
# 1  female     2.0  28.0
# 2  female     3.0  22.0
# 3    male     1.0  42.0
# 4    male     2.0  29.5
# 5    male     3.0  25.0

# %%
def impute_age(row):
    condition = (
        (df_age_median['sex'] == row['sex']) &
        (df_age_median['pclass'] == row['pclass'])
    )
    # Check if there are rows that meet the condition
    if condition.any():
        return df_age_median[condition]['age'].values[0]
    else:
        # Handle the case where there are no matching rows
        return None  # You can choose an appropriate value for missing age here

# Apply the impute_age function to fill missing values in 'Age' column
df['age'] = df.apply(lambda row: impute_age(row) if pd.isnull(row['age']) else row['age'], axis=1)

# %% [markdown]
# # sex column

# %%
le = LabelEncoder()
df['sex'] = le.fit_transform(df['sex'])

# %%
df.head()
# Out:
#    PassengerId  pclass  survived  \
# 0          1.0     1.0       1.0
# 1          2.0     1.0       1.0
# 2          3.0     1.0       0.0
# 3          4.0     1.0       0.0
# 4          5.0     1.0       0.0
#
#                                               name  sex      age  sibsp  \
# 0                    Allen, Miss. Elisabeth Walton    0  29.0000    0.0
# 1                   Allison, Master. Hudson Trevor    1   0.9167    1.0
# 2                     Allison, Miss. Helen Loraine    0   2.0000    1.0
# 3             Allison, Mr. Hudson Joshua Creighton    1  30.0000    1.0
# 4  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)    0  25.0000    1.0
#
#    parch  ticket      fare    cabin embarked boat   body  \
# 0    0.0   24160  211.3375       B5        S    2    NaN
# 1    2.0  113781  151.5500  C22 C26        S   11    NaN
# 2    2.0  113781  151.5500  C22 C26        S  NaN    NaN
# 3    2.0  113781  151.5500  C22 C26        S  NaN  135.0
# 4    2.0  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %% [markdown]
# # cabin column

# %%
# Fill missing "Cabin" values based on passenger class
class_cabin_mapping = df.groupby('pclass')['cabin'].transform(lambda x: x.fillna(x.mode()[0]))
# Update the "Cabin" column with the imputed values
df['cabin'] = class_cabin_mapping
df.head()
# Out:
#    PassengerId  pclass  survived  \
# 0          1.0     1.0       1.0
# 1          2.0     1.0       1.0
# 2          3.0     1.0       0.0
# 3          4.0     1.0       0.0
# 4          5.0     1.0       0.0
#
#                                               name  sex      age  sibsp  \
# 0                    Allen, Miss. Elisabeth Walton    0  29.0000    0.0
# 1                   Allison, Master. Hudson Trevor    1   0.9167    1.0
# 2                     Allison, Miss. Helen Loraine    0   2.0000    1.0
# 3             Allison, Mr. Hudson Joshua Creighton    1  30.0000    1.0
# 4  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)    0  25.0000    1.0
#
#    parch  ticket      fare    cabin embarked boat   body  \
# 0    0.0   24160  211.3375       B5        S    2    NaN
# 1    2.0  113781  151.5500  C22 C26        S   11    NaN
# 2    2.0  113781  151.5500  C22 C26        S  NaN    NaN
# 3    2.0  113781  151.5500  C22 C26        S  NaN  135.0
# 4    2.0  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %% [markdown]
# # boat column

# %%
df['boat'].isnull().sum()
# Out:
# 823

# %% [markdown]
# #### NaNs Value of boat and survived : 1

# %%
df[(df['survived'] == 1) & (df['boat'].isnull())]#.fillna(value = {"boat": df['boat'].mode()[0]})
# Out:
#       PassengerId  pclass  survived  \
# 192         193.0     1.0       1.0
# 358         359.0     2.0       1.0
# 395         396.0     2.0       1.0
# 396         397.0     2.0       1.0
# 458         459.0     2.0       1.0
# 489         490.0     2.0       1.0
# 513         514.0     2.0       1.0
# 545         546.0     2.0       1.0
# 572         573.0     2.0       1.0
# 656         657.0     3.0       1.0
# 780         781.0     3.0       1.0
# 860         861.0     3.0       1.0
# 870         871.0     3.0       1.0
# 926         927.0     3.0       1.0
# 1000       1001.0     3.0       1.0
# 1007       1008.0     3.0       1.0
# 1037       1038.0     3.0       1.0
# 1071       1072.0     3.0       1.0
# 1078       1079.0     3.0       1.0
# 1094       1095.0     3.0       1.0
# 1198       1199.0     3.0       1.0
# 1290       1291.0     3.0       1.0
# 1300       1301.0     3.0       1.0
#
#                                                    name  sex   age  sibsp  \
# 192                                Lurette, Miss. Elise    0  58.0    0.0
# 358                            Bystrom, Mrs. (Karolina)    0  42.0    0.0
# 395                                 Doling, Miss. Elsie    0  18.0    0.0
# 396                Doling, Mrs. John T (Ada Julia Bone)    0  34.0    0.0
# 458                                 Ilett, Miss. Bertha    0  17.0    0.0
# 489   Louch, Mrs. Charles Alexander (Alice Adelaide ...    0  42.0    1.0
# 513                 Nasser, Mrs. Nicholas (Adele Achem)    0  14.0    1.0
# 545         Renouf, Mrs. Peter Henry (Lillian Jefferys)    0  30.0    3.0
# 572                    Trout, Mrs. William H (Jessie L)    0  28.0    0.0
# 656   Backstrom, Mrs. Karl Alfred (Maria Mathilda Gu...    0  33.0    3.0
# 780                               Drapkin, Miss. Jennie    0  23.0    0.0
# 860                              Heikkinen, Miss. Laina    0  26.0    0.0
# 870                              Honkanen, Miss. Eliina    0  27.0    0.0
# 926                                   Kennedy, Mr. John    1  25.0    0.0
# 1000                       McCormack, Mr. Thomas Joseph    1  25.0    0.0
# 1007                        McGowan, Miss. Anna "Annie"    0  15.0    0.0
# 1037                     Moussa, Mrs. (Mantoura Boulos)    0  22.0    0.0
# 1071    O'Brien, Mrs. Thomas (Johanna "Hannah" Godfrey)    0  22.0    1.0
# 1078                      O'Dwyer, Miss. Ellen "Nellie"    0  22.0    0.0
# 1094                                   Osman, Mrs. Mara    0  31.0    0.0
# 1198                         Shine, Miss. Ellen Natalia    0  22.0    0.0
# 1290                   Wilkes, Mrs. James (Ellen Needs)    0  47.0    1.0
# 1300            Yasbeck, Mrs. Antoni (Selini Alexander)    0  15.0    1.0
#
#       parch            ticket      fare cabin embarked boat  body  \
# 192     0.0          PC 17569  146.5208   B80        C  NaN   NaN
# 358     0.0            236852   13.0000     D        S  NaN   NaN
# 395     1.0            231919   23.0000     D        S  NaN   NaN
# 396     1.0            231919   23.0000     D        S  NaN   NaN
# 458     0.0        SO/C 14885   10.5000     D        S  NaN   NaN
# 489     0.0        SC/AH 3085   26.0000     D        S  NaN   NaN
# 513     0.0            237736   30.0708     D        C  NaN   NaN
# 545     0.0             31027   21.0000     D        S  NaN   NaN
# 572     0.0            240929   12.6500     D        S  NaN   NaN
# 656     0.0           3101278   15.8500    G6        S  NaN   NaN
# 780     0.0   SOTON/OQ 392083    8.0500    G6        S  NaN   NaN
# 860     0.0  STON/O2. 3101282    7.9250    G6        S  NaN   NaN
# 870     0.0  STON/O2. 3101283    7.9250    G6        S  NaN   NaN
# 926     0.0            368783    7.7500    G6        Q  NaN   NaN
# 1000    0.0            367228    7.7500    G6        Q  NaN   NaN
# 1007    0.0            330923    8.0292    G6        Q  NaN   NaN
# 1037    0.0              2626    7.2292    G6        C  NaN   NaN
# 1071    0.0            370365   15.5000    G6        Q  NaN   NaN
# 1078    0.0            330959    7.8792    G6        Q  NaN   NaN
# 1094    0.0            349244    8.6833    G6        S  NaN   NaN
# 1198    0.0            330968    7.7792    G6        Q  NaN   NaN
# 1290    0.0            363272    7.0000    G6        S  NaN   NaN
# 1300    0.0              2659   14.4542    G6        C  NaN   NaN
#
#                                 home.dest
# 192                                   NaN
# 358                          New York, NY
# 395                           Southampton
# 396                           Southampton
# 458                              Guernsey
# 489           Weston-Super-Mare, Somerset
# 513                          New York, NY
# 545                         Elizabeth, NJ
# 572                          Columbus, OH
# 656   Ruotsinphytaa, Finland New York, NY
# 780                   London New York, NY
# 860                                   NaN
# 870                                   NaN
# 926                                   NaN
# 1000                                  NaN
# 1007                                  NaN
# 1037                                  NaN
# 1071                                  NaN
# 1078                                  NaN
# 1094                                  NaN
# 1198                                  NaN
# 1290                                  NaN
# 1300                                  NaN

# %%
# condition for filling missing values
condition = (df['survived'] == 1) & (df['boat'].isnull())

# Calculate the mode of the "boat" column
boat_mode = df['boat'].mode()[0]

# Use fillna() to replace missing values based on the condition
df.loc[condition, 'boat'] = boat_mode

# %%
df['boat'].isnull().sum()
# Out:
# 800

# %% [markdown]
# #### NaNs Value of boat and survived : 0

# %%
#imputing based on Pclass and Sex
boat_mode_by_class_sex = df.groupby(['pclass', 'sex'])['boat'].transform(lambda x: x.mode()[0])
df['boat'].fillna(boat_mode_by_class_sex, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1309 entries, 0 to 1308
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   float64
#  1   pclass       1309 non-null   float64
#  2   survived     1309 non-null   float64
#  3   name         1309 non-null   object
#  4   sex          1309 non-null   int32
#  5   age          1309 non-null   float64
#  6   sibsp        1309 non-null   float64
#  7   parch        1309 non-null   float64
#  8   ticket       1309 non-null   object
#  9   fare         1308 non-null   float64
#  10  cabin        1309 non-null   object
#  11  embarked     1307 non-null   object
#  12  boat         1309 non-null   object
#  13  body         121 non-null    float64
#  14  home.dest    745 non-null    object
# dtypes: float64(8), int32(1), object(6)
# memory usage: 158.5+ KB

# %% [markdown]
# # ticket column

# %%
drop_unused_columns(df, columns=['ticket'])

# %% [markdown]
# # fare column

# %%
df['fare'].fillna(method='bfill', inplace = True)

# %%
# min_max_scaler(df, ['fare'])

# %%
df.head()
# Out:
#    PassengerId  pclass  survived  \
# 0          1.0     1.0       1.0
# 1          2.0     1.0       1.0
# 2          3.0     1.0       0.0
# 3          4.0     1.0       0.0
# 4          5.0     1.0       0.0
#
#                                               name  sex      age  sibsp  \
# 0                    Allen, Miss. Elisabeth Walton    0  29.0000    0.0
# 1                   Allison, Master. Hudson Trevor    1   0.9167    1.0
# 2                     Allison, Miss. Helen Loraine    0   2.0000    1.0
# 3             Allison, Mr. Hudson Joshua Creighton    1  30.0000    1.0
# 4  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)    0  25.0000    1.0
#
#    parch      fare    cabin embarked boat   body  \
# 0    0.0  211.3375       B5        S    2    NaN
# 1    2.0  151.5500  C22 C26        S   11    NaN
# 2    2.0  151.5500  C22 C26        S    8    NaN
# 3    2.0  151.5500  C22 C26        S    3  135.0
# 4    2.0  151.5500  C22 C26        S    8    NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %% [markdown]
# # cabin column

# %%
df['Cabin_Deck'] = df['cabin'].str[0]

# %%
df['Has_Cabin'] = df['cabin'].notna().astype(int)

# %%
drop_unused_columns(df, columns=['cabin'])

# %%
df.head()
# Out:
#    PassengerId  pclass  survived  \
# 0          1.0     1.0       1.0
# 1          2.0     1.0       1.0
# 2          3.0     1.0       0.0
# 3          4.0     1.0       0.0
# 4          5.0     1.0       0.0
#
#                                               name  sex      age  sibsp  \
# 0                    Allen, Miss. Elisabeth Walton    0  29.0000    0.0
# 1                   Allison, Master. Hudson Trevor    1   0.9167    1.0
# 2                     Allison, Miss. Helen Loraine    0   2.0000    1.0
# 3             Allison, Mr. Hudson Joshua Creighton    1  30.0000    1.0
# 4  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)    0  25.0000    1.0
#
#    parch      fare embarked boat   body                        home.dest  \
# 0    0.0  211.3375        S    2    NaN                     St Louis, MO
# 1    2.0  151.5500        S   11    NaN  Montreal, PQ / Chesterville, ON
# 2    2.0  151.5500        S    8    NaN  Montreal, PQ / Chesterville, ON
# 3    2.0  151.5500        S    3  135.0  Montreal, PQ / Chesterville, ON
# 4    2.0  151.5500        S    8    NaN  Montreal, PQ / Chesterville, ON
#
#   Cabin_Deck  Has_Cabin
# 0          B          1
# 1          C          1
# 2          C          1
# 3          C          1
# 4          C          1

# %% [markdown]
# # Cabin_Deck Column

# %%
df = labelencoder(df, columns=['Cabin_Deck'])

# %% [markdown]
# # home.dest column

# %%
drop_unused_columns(df, columns=['home.dest'])

# %% [markdown]
# # body column

# %%
drop_unused_columns(df, columns=['body'])

# %% [markdown]
# # change data type

# %%
def change_data_type(df):
    df['fare'] = round(df["fare"], 0)
    df = df.astype({'pclass': 'int','survived' : 'int' ,'PassengerId': 'int', 'pclass' : 'int', 'age' : 'int', 'sibsp': 'int', 'parch' : 'int'})
    return df

# %%
df = change_data_type(df)

# %% [markdown]
# # embarked column

# %%
# df = labelencoder(df, columns=['embarked'])

# %%
df.head()
# Out:
#    PassengerId  pclass  survived  \
# 0            1       1         1
# 1            2       1         1
# 2            3       1         0
# 3            4       1         0
# 4            5       1         0
#
#                                               name  sex  age  sibsp  parch  \
# 0                    Allen, Miss. Elisabeth Walton    0   29      0      0
# 1                   Allison, Master. Hudson Trevor    1    0      1      2
# 2                     Allison, Miss. Helen Loraine    0    2      1      2
# 3             Allison, Mr. Hudson Joshua Creighton    1   30      1      2
# 4  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)    0   25      1      2
#
#     fare embarked boat  Cabin_Deck  Has_Cabin
# 0  211.0        S    2           1          1
# 1  152.0        S   11           2          1
# 2  152.0        S    8           2          1
# 3  152.0        S    3           2          1
# 4  152.0        S    8           2          1

# %% [markdown]
# # name column

# %% [markdown]
# #### extract title

# %%
df[['last_name', 'title', 'first_name', 'middle_name']] = df['name'].str.split(', |\.', expand=True)

# %%
drop_unused_columns(df, columns=['name', 'middle_name'])

# %%
df.head()
# Out:
#    PassengerId  pclass  survived  sex  age  sibsp  parch   fare embarked boat  \
# 0            1       1         1    0   29      0      0  211.0        S    2
# 1            2       1         1    1    0      1      2  152.0        S   11
# 2            3       1         0    0    2      1      2  152.0        S    8
# 3            4       1         0    1   30      1      2  152.0        S    3
# 4            5       1         0    0   25      1      2  152.0        S    8
#
#    Cabin_Deck  Has_Cabin last_name   title                          first_name
# 0           1          1     Allen    Miss                    Elisabeth Walton
# 1           2          1   Allison  Master                       Hudson Trevor
# 2           2          1   Allison    Miss                       Helen Loraine
# 3           2          1   Allison      Mr             Hudson Joshua Creighton
# 4           2          1   Allison     Mrs   Hudson J C (Bessie Waldo Daniels)

# %% [markdown]
# # change columns order

# %%
df = df[['PassengerId','title', 'last_name', 'first_name', 'pclass', 'survived', 'sex', 'age', 'sibsp', 'parch', 'fare', 'embarked',
                 'boat', 'Cabin_Deck', 'Has_Cabin']]

# %%
df.head()
# Out:
#    PassengerId   title last_name                          first_name  pclass  \
# 0            1    Miss     Allen                    Elisabeth Walton       1
# 1            2  Master   Allison                       Hudson Trevor       1
# 2            3    Miss   Allison                       Helen Loraine       1
# 3            4      Mr   Allison             Hudson Joshua Creighton       1
# 4            5     Mrs   Allison   Hudson J C (Bessie Waldo Daniels)       1
#
#    survived  sex  age  sibsp  parch   fare embarked boat  Cabin_Deck  \
# 0         1    0   29      0      0  211.0        S    2           1
# 1         1    1    0      1      2  152.0        S   11           2
# 2         0    0    2      1      2  152.0        S    8           2
# 3         0    1   30      1      2  152.0        S    3           2
# 4         0    0   25      1      2  152.0        S    8           2
#
#    Has_Cabin
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1309 entries, 0 to 1308
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int32
#  1   title        1309 non-null   object
#  2   last_name    1309 non-null   object
#  3   first_name   1309 non-null   object
#  4   pclass       1309 non-null   int32
#  5   survived     1309 non-null   int32
#  6   sex          1309 non-null   int32
#  7   age          1309 non-null   int32
#  8   sibsp        1309 non-null   int32
#  9   parch        1309 non-null   int32
#  10  fare         1309 non-null   float64
#  11  embarked     1307 non-null   object
#  12  boat         1309 non-null   object
#  13  Cabin_Deck   1309 non-null   int32
#  14  Has_Cabin    1309 non-null   int32
# dtypes: float64(1), int32(9), object(5)
# memory usage: 117.6+ KB
