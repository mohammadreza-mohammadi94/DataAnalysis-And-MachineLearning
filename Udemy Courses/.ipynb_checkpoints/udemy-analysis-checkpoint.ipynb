# %% [markdown]
# # Udemy courses dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load dataset and first evaluation of df

# %%
df = pd.read_csv('Udemy-Dataset.csv')

# %%
df.head()
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2    1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3    1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4    1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
# 2    75              482            1            47  Intermediate Level
# 3    75              850            3            43  Intermediate Level
# 4    75              940            3            32  Intermediate Level
#
#   content_duration   published_timestamp              subject
# 0        1.5 hours  2014-09-18T05:07:05Z  Musical Instruments
# 1           1 hour  2017-04-12T19:06:34Z  Musical Instruments
# 2        1.5 hours  2017-04-26T18:34:57Z  Musical Instruments
# 3           1 hour  2017-02-21T23:48:18Z  Musical Instruments
# 4          37 mins  2017-02-21T23:44:49Z  Musical Instruments

# %%
# genegral information about dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3682 entries, 0 to 3681
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3682 non-null   int64
#  1   course_title         3682 non-null   object
#  2   is_paid              3682 non-null   bool
#  3   price                3682 non-null   object
#  4   num_subscribers      3682 non-null   int64
#  5   num_reviews          3682 non-null   int64
#  6   num_lectures         3682 non-null   int64
#  7   level                3682 non-null   object
#  8   content_duration     3682 non-null   object
#  9   published_timestamp  3682 non-null   object
#  10  subject              3682 non-null   object
# dtypes: bool(1), int64(4), object(6)
# memory usage: 291.4+ KB

# %%
df.columns
# Out:
# Index(['course_id', 'course_title', 'is_paid', 'price', 'num_subscribers',
#        'num_reviews', 'num_lectures', 'level', 'content_duration',
#        'published_timestamp', 'subject'],
#       dtype='object')

# %%
# check some statistical analysis of the dataset using describe method
df.describe()
# Out:
#           course_id  num_subscribers   num_reviews  num_lectures
# count  3.682000e+03      3682.000000   3682.000000   3682.000000
# mean   6.766121e+05      3194.230310    156.093156     40.065182
# std    3.436355e+05      9499.378361    934.957204     50.373299
# min    8.324000e+03         0.000000      0.000000      0.000000
# 25%    4.078430e+05       110.250000      4.000000     15.000000
# 50%    6.885580e+05       911.500000     18.000000     25.000000
# 75%    9.617515e+05      2540.250000     67.000000     45.000000
# max    1.282064e+06    268923.000000  27445.000000    779.000000

# %%
# check str columns
df.select_dtypes(include='object')
# Out:
#                                            course_title price  \
# 0     #1 Piano Hand Coordination: Play 10th Ballad i...    35
# 1     #10 Hand Coordination - Transfer Chord Ballad ...    75
# 2     #12 Hand Coordination: Let your Hands dance wi...    75
# 3     #4 Piano Hand Coordination: Fun Piano Runs in ...    75
# 4     #5  Piano Hand Coordination:  Piano Runs in 2 ...    75
# ...                                                 ...   ...
# 3677  Your Own Site in 45 Min: The Complete Wordpres...   120
# 3678    Your Second Course on Piano: Two Handed Playing    70
# 3679  Zend Framework 2: Learn the PHP framework ZF2 ...    40
# 3680  Zoho Books Gestion Financière d'Entreprise pas...  Free
# 3681                Zombie Apocalypse Photoshop Actions    50
#
#                    level content_duration   published_timestamp  \
# 0             All Levels        1.5 hours  2014-09-18T05:07:05Z
# 1     Intermediate Level           1 hour  2017-04-12T19:06:34Z
# 2     Intermediate Level        1.5 hours  2017-04-26T18:34:57Z
# 3     Intermediate Level           1 hour  2017-02-21T23:48:18Z
# 4     Intermediate Level          37 mins  2017-02-21T23:44:49Z
# ...                  ...              ...                   ...
# 3677          All Levels          4 hours  2015-04-20T22:15:17Z
# 3678      Beginner Level          5 hours  2015-10-26T20:04:21Z
# 3679          All Levels        6.5 hours  2015-11-11T18:55:45Z
# 3680          All Levels          2 hours  2017-05-26T16:45:55Z
# 3681          All Levels        1.5 hours  2016-09-26T22:19:48Z
#
#                   subject
# 0     Musical Instruments
# 1     Musical Instruments
# 2     Musical Instruments
# 3     Musical Instruments
# 4     Musical Instruments
# ...                   ...
# 3677      Web Development
# 3678  Musical Instruments
# 3679      Web Development
# 3680     Business Finance
# 3681       Graphic Design
#
# [3682 rows x 6 columns]

# %%
# check missing values
df.isnull().sum()
# Out:
# course_id              0
# course_title           0
# is_paid                0
# price                  0
# num_subscribers        0
# num_reviews            0
# num_lectures           0
# level                  0
# content_duration       0
# published_timestamp    0
# subject                0
# dtype: int64

# %%
# number of unique values 
df.nunique()
# Out:
# course_id              3676
# course_title           3667
# is_paid                   2
# price                    38
# num_subscribers        2198
# num_reviews             511
# num_lectures            229
# level                     4
# content_duration        109
# published_timestamp    3676
# subject                   4
# dtype: int64

# %% [markdown]
# # Data Cleaning
# __Correcting feature's dtypes and values__

# %% [markdown]
# ### Check duplicates values

# %%
# check duplicats
df.duplicated().sum()
# Out:
# 6

# %%
# drop duplicate rows
df.drop_duplicates(inplace = True)

# %% [markdown]
# ### Correct dtype of `published_timestamp`

# %%
# changing published_timestamp dtype to datetime
df['published_timestamp'] = pd.to_datetime(df['published_timestamp'])

# %% [markdown]
# #### ___Seperating Date from 'published_timestamp' column___

# %%
df['Date'] = df['published_timestamp'].dt.date

# %%
# changint Date & Time dtype to datetime
df['Date'] = pd.to_datetime(df['Date'])
df['Date'] = df['Date'].dt.year

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3676 entries, 0 to 3681
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3676 non-null   int64
#  1   course_title         3676 non-null   object
#  2   is_paid              3676 non-null   bool
#  3   price                3676 non-null   object
#  4   num_subscribers      3676 non-null   int64
#  5   num_reviews          3676 non-null   int64
#  6   num_lectures         3676 non-null   int64
#  7   level                3676 non-null   object
#  8   content_duration     3676 non-null   object
#  9   published_timestamp  3676 non-null   datetime64[ns, UTC]
#  10  subject              3676 non-null   object
#  11  Date                 3676 non-null   int32
# dtypes: bool(1), datetime64[ns, UTC](1), int32(1), int64(4), object(5)
# memory usage: 333.9+ KB

# %% [markdown]
# ### Correcting `price` column

# %%
# Convert numeric values to int and mark 'Free' courses
df['price'] = pd.to_numeric(df['price'], errors='coerce')  # Convert to numeric, coerce errors to NaN

# %%
# filling NaN values of price column to 0 indicating that course is free of charge
df['price'] = df['price'].fillna(0)

# %%
# check if correction has been reflected on df
df[df['is_paid'] == False]
# Out:
#       course_id                                       course_title  is_paid  \
# 41       286070        5 lecciones que todo guitarrista debe tomar    False
# 49       696630  7 Ways A Beginner Guitarist Can Sound Better, ...    False
# 57       955914  A beginner`s guide to fingerpicking and strumm...    False
# 67       270976                             A how to guide in HTML    False
# 74      1214144  ¡Triunfar en La Bolsa de Valores No Requiere d...    False
# ...         ...                                                ...      ...
# 3620     552598  WordPress in under an hour - Create/manage you...    False
# 3638    1068590                     Wordpress Website Mastery 2017    False
# 3652     752706  Write quicker HTML5 and CSS 3; productivity ha...    False
# 3674    1257976  Your First 10 Guitar Lessons - Learn how to pl...    False
# 3680    1225194  Zoho Books Gestion Financière d'Entreprise pas...    False
#
#       price  num_subscribers  num_reviews  num_lectures           level  \
# 41      0.0             4452          263            14  Beginner Level
# 49      0.0             4529          193             7  Beginner Level
# 57      0.0             3481           29            20  Beginner Level
# 67      0.0             7318          205             8  Beginner Level
# 74      0.0              338            7             6  Beginner Level
# ...     ...              ...          ...           ...             ...
# 3620    0.0             6474           86            15      All Levels
# 3638    0.0             5181           64            22  Beginner Level
# 3652    0.0            13016          286            15      All Levels
# 3674    0.0              924            4            18  Beginner Level
# 3680    0.0              229            0            33      All Levels
#
#      content_duration       published_timestamp              subject  Date
# 41             1 hour 2014-08-23 05:08:14+00:00  Musical Instruments  2014
# 49            36 mins 2015-12-21 18:50:50+00:00  Musical Instruments  2015
# 57            2 hours 2016-09-13 21:51:59+00:00  Musical Instruments  2016
# 67            35 mins 2014-08-10 20:19:10+00:00      Web Development  2014
# 74             1 hour 2017-05-30 14:30:12+00:00     Business Finance  2017
# ...               ...                       ...                  ...   ...
# 3620           1 hour 2015-07-15 00:21:56+00:00      Web Development  2015
# 3638        2.5 hours 2017-01-18 17:01:40+00:00      Web Development  2017
# 3652        1.5 hours 2016-03-03 17:45:31+00:00      Web Development  2016
# 3674           1 hour 2017-06-29 00:29:36+00:00  Musical Instruments  2017
# 3680          2 hours 2017-05-26 16:45:55+00:00     Business Finance  2017
#
# [310 rows x 12 columns]

# %% [markdown]
# ### Correcting `content_duration` values and dtypes to minutes

# %%
def extract_numeric_value(value):
    try:
        if 'hour' in value or 'hours' in value:
            return pd.to_numeric(value.split()[0]) * 60
        elif 'min' in value or 'mins' in value:
            return pd.to_numeric(value.split()[0])
        else:
            return None  
    except Exception as e:
        print(f"Error: {e}")
        return None

# %%
df['content_duration'] = df['content_duration'].apply(extract_numeric_value)

# %%
# check if previous function has been affected correctly
df.iloc[3672]
# Out:
# course_id                                                       552700
# course_title           Your Second Course on Piano: Two Handed Playing
# is_paid                                                           True
# price                                                             70.0
# num_subscribers                                                   1018
# num_reviews                                                         12
# num_lectures                                                        22
# level                                                   Beginner Level
# content_duration                                                 300.0
# published_timestamp                          2015-10-26 20:04:21+00:00
# subject                                            Musical Instruments
# Date                                                              2015
# Name: 3678, dtype: object

# %%
# check if previous function has been affected correctly
df.iloc[4]
# Out:
# course_id                                                        1120410
# course_title           #5  Piano Hand Coordination:  Piano Runs in 2 ...
# is_paid                                                             True
# price                                                               75.0
# num_subscribers                                                      940
# num_reviews                                                            3
# num_lectures                                                          32
# level                                                 Intermediate Level
# content_duration                                                    37.0
# published_timestamp                            2017-02-21 23:44:49+00:00
# subject                                              Musical Instruments
# Date                                                                2017
# Name: 4, dtype: object

# %% [markdown]
# # Renaming columns and reorder them

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3676 entries, 0 to 3681
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3676 non-null   int64
#  1   course_title         3676 non-null   object
#  2   is_paid              3676 non-null   bool
#  3   price                3676 non-null   float64
#  4   num_subscribers      3676 non-null   int64
#  5   num_reviews          3676 non-null   int64
#  6   num_lectures         3676 non-null   int64
#  7   level                3676 non-null   object
#  8   content_duration     3671 non-null   float64
#  9   published_timestamp  3676 non-null   datetime64[ns, UTC]
#  10  subject              3676 non-null   object
#  11  Date                 3676 non-null   int32
# dtypes: bool(1), datetime64[ns, UTC](1), float64(2), int32(1), int64(4), object(3)
# memory usage: 333.9+ KB

# %%
# drop unuseable columns
df.drop(columns= ['published_timestamp'], inplace = True)

# %%
df = df.rename(columns= {
    'course_id' : 'id',
    'course_title' : 'title',
    'num_subscribers' : 'subscribes',
    'num_reviews' : 'reviews',
    'num_lectures' : 'lectures',
    'content_duration' : 'duration_minutes',
    'Date' : 'publish_date'
})

# %%
# re-oder them
df = df[['id', 'title', 'subject', 'level', 'duration_minutes', 'lectures', 'price', 'is_paid', 'subscribes', 'reviews', 'publish_date']].reset_index(drop = True)

# %%
df.head()
# Out:
#         id                                              title  \
# 0   288942  #1 Piano Hand Coordination: Play 10th Ballad i...
# 1  1170074  #10 Hand Coordination - Transfer Chord Ballad ...
# 2  1193886  #12 Hand Coordination: Let your Hands dance wi...
# 3  1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...
# 4  1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...
#
#                subject               level  duration_minutes  lectures  price  \
# 0  Musical Instruments          All Levels              90.0        68   35.0
# 1  Musical Instruments  Intermediate Level              60.0        41   75.0
# 2  Musical Instruments  Intermediate Level              90.0        47   75.0
# 3  Musical Instruments  Intermediate Level              60.0        43   75.0
# 4  Musical Instruments  Intermediate Level              37.0        32   75.0
#
#    is_paid  subscribes  reviews  publish_date
# 0     True        3137       18          2014
# 1     True        1593        1          2017
# 2     True         482        1          2017
# 3     True         850        3          2017
# 4     True         940        3          2017

# %% [markdown]
# ____________________________________

# %% [markdown]
# # Analyzing dataframe's features values

# %%
df.hist(figsize = (20, 8), bins = 100)
# Out:
# array([[<AxesSubplot:title={'center':'id'}>,
#         <AxesSubplot:title={'center':'duration_minutes'}>,
#         <AxesSubplot:title={'center':'lectures'}>],
#        [<AxesSubplot:title={'center':'price'}>,
#         <AxesSubplot:title={'center':'subscribes'}>,
#         <AxesSubplot:title={'center':'reviews'}>],
#        [<AxesSubplot:title={'center':'publish_date'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %% [markdown]
# ### All unique values for `subjects` column

# %%
df['subject'].unique()
# Out:
# array(['Musical Instruments', 'Business Finance', 'Graphic Design',
#        'Web Development'], dtype=object)

# %% [markdown]
# ### Subjects which have most number of courses on `subject` column

# %%
df['subject'].value_counts()
# Out:
# subject
# Web Development        1199
# Business Finance       1195
# Musical Instruments     680
# Graphic Design          602
# Name: count, dtype: int64

# %% [markdown]
# ### All free courses

# %%
df[(df['is_paid'] == False)]
# Out:
#            id                                              title  \
# 41     286070        5 lecciones que todo guitarrista debe tomar
# 49     696630  7 Ways A Beginner Guitarist Can Sound Better, ...
# 57     955914  A beginner`s guide to fingerpicking and strumm...
# 67     270976                             A how to guide in HTML
# 74    1214144  ¡Triunfar en La Bolsa de Valores No Requiere d...
# ...       ...                                                ...
# 3614   552598  WordPress in under an hour - Create/manage you...
# 3632  1068590                     Wordpress Website Mastery 2017
# 3646   752706  Write quicker HTML5 and CSS 3; productivity ha...
# 3668  1257976  Your First 10 Guitar Lessons - Learn how to pl...
# 3674  1225194  Zoho Books Gestion Financière d'Entreprise pas...
#
#                   subject           level  duration_minutes  lectures  price  \
# 41    Musical Instruments  Beginner Level              60.0        14    0.0
# 49    Musical Instruments  Beginner Level              36.0         7    0.0
# 57    Musical Instruments  Beginner Level             120.0        20    0.0
# 67        Web Development  Beginner Level              35.0         8    0.0
# 74       Business Finance  Beginner Level              60.0         6    0.0
# ...                   ...             ...               ...       ...    ...
# 3614      Web Development      All Levels              60.0        15    0.0
# 3632      Web Development  Beginner Level             150.0        22    0.0
# 3646      Web Development      All Levels              90.0        15    0.0
# 3668  Musical Instruments  Beginner Level              60.0        18    0.0
# 3674     Business Finance      All Levels             120.0        33    0.0
#
#       is_paid  subscribes  reviews  publish_date
# 41      False        4452      263          2014
# 49      False        4529      193          2015
# 57      False        3481       29          2016
# 67      False        7318      205          2014
# 74      False         338        7          2017
# ...       ...         ...      ...           ...
# 3614    False        6474       86          2015
# 3632    False        5181       64          2017
# 3646    False       13016      286          2016
# 3668    False         924        4          2017
# 3674    False         229        0          2017
#
# [310 rows x 11 columns]

# %%
# create new datafram of free courses
free = df[(df['is_paid'] == False)].reset_index()
free.head()
# Out:
#    index       id                                              title  \
# 0     41   286070        5 lecciones que todo guitarrista debe tomar
# 1     49   696630  7 Ways A Beginner Guitarist Can Sound Better, ...
# 2     57   955914  A beginner`s guide to fingerpicking and strumm...
# 3     67   270976                             A how to guide in HTML
# 4     74  1214144  ¡Triunfar en La Bolsa de Valores No Requiere d...
#
#                subject           level  duration_minutes  lectures  price  \
# 0  Musical Instruments  Beginner Level              60.0        14    0.0
# 1  Musical Instruments  Beginner Level              36.0         7    0.0
# 2  Musical Instruments  Beginner Level             120.0        20    0.0
# 3      Web Development  Beginner Level              35.0         8    0.0
# 4     Business Finance  Beginner Level              60.0         6    0.0
#
#    is_paid  subscribes  reviews  publish_date
# 0    False        4452      263          2014
# 1    False        4529      193          2015
# 2    False        3481       29          2016
# 3    False        7318      205          2014
# 4    False         338        7          2017

# %% [markdown]
# ### All paid courses

# %%
df[(df['is_paid'] == True)]
# Out:
#            id                                              title  \
# 0      288942  #1 Piano Hand Coordination: Play 10th Ballad i...
# 1     1170074  #10 Hand Coordination - Transfer Chord Ballad ...
# 2     1193886  #12 Hand Coordination: Let your Hands dance wi...
# 3     1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...
# 4     1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...
# ...       ...                                                ...
# 3670   498488  Your First Successful Forex Trades - With Case...
# 3671   328960  Your Own Site in 45 Min: The Complete Wordpres...
# 3672   552700    Your Second Course on Piano: Two Handed Playing
# 3673   631754  Zend Framework 2: Learn the PHP framework ZF2 ...
# 3675   964478                Zombie Apocalypse Photoshop Actions
#
#                   subject               level  duration_minutes  lectures  \
# 0     Musical Instruments          All Levels              90.0        68
# 1     Musical Instruments  Intermediate Level              60.0        41
# 2     Musical Instruments  Intermediate Level              90.0        47
# 3     Musical Instruments  Intermediate Level              60.0        43
# 4     Musical Instruments  Intermediate Level              37.0        32
# ...                   ...                 ...               ...       ...
# 3670     Business Finance          All Levels             150.0        16
# 3671      Web Development          All Levels             240.0        36
# 3672  Musical Instruments      Beginner Level             300.0        22
# 3673      Web Development          All Levels             390.0        37
# 3675       Graphic Design          All Levels              90.0        15
#
#       price  is_paid  subscribes  reviews  publish_date
# 0      35.0     True        3137       18          2014
# 1      75.0     True        1593        1          2017
# 2      75.0     True         482        1          2017
# 3      75.0     True         850        3          2017
# 4      75.0     True         940        3          2017
# ...     ...      ...         ...      ...           ...
# 3670  200.0     True        1079       34          2015
# 3671  120.0     True        1566       29          2015
# 3672   70.0     True        1018       12          2015
# 3673   40.0     True         723      130          2015
# 3675   50.0     True          12        1          2016
#
# [3366 rows x 11 columns]

# %%
# create new dataframe of paid courses
paid = df[(df['is_paid'] == True)].reset_index()

# %% [markdown]
# ### Top selling courses

# %%
df.sort_values(by='subscribes', ascending = False)
# Out:
#            id                                              title  \
# 2227    41295               Learn HTML5 Programming From Scratch
# 775     59014                     Coding for Entrepreneurs Basic
# 3380   625204                         The Web Developer Bootcamp
# 640    173548  Build Your First Website in 1 Week with HTML5 ...
# 3311   764164              The Complete Web Developer Course 2.0
# ...       ...                                                ...
# 403   1221942                                  Basic Bookkeeping
# 2592   185526                             MicroStation - Células
# 993    603902             Curso de Didgeridoo nivel principiante
# 476   1252410  Beginners Guide to Kindle Ebook Covers Design ...
# 2415  1058852            Learn to trade using technical analysis
#
#                   subject               level  duration_minutes  lectures  \
# 2227      Web Development          All Levels             630.0        45
# 775       Web Development      Beginner Level             210.0        27
# 3380      Web Development          All Levels            2580.0       342
# 640       Web Development      Beginner Level             180.0        30
# 3311      Web Development          All Levels            1830.0       304
# ...                   ...                 ...               ...       ...
# 403      Business Finance      Beginner Level              44.0        12
# 2592       Graphic Design      Beginner Level              37.0         9
# 993   Musical Instruments      Beginner Level              60.0        31
# 476        Graphic Design          All Levels              90.0        16
# 2415     Business Finance  Intermediate Level              32.0         6
#
#       price  is_paid  subscribes  reviews  publish_date
# 2227    0.0    False      268923     8629          2013
# 775     0.0    False      161029      279          2013
# 3380  200.0     True      121584    27445          2015
# 640     0.0    False      120291     5924          2014
# 3311  200.0     True      114512    22412          2016
# ...     ...      ...         ...      ...           ...
# 403    35.0     True           0        0          2017
# 2592   20.0     True           0        0          2014
# 993    50.0     True           0        0          2016
# 476    20.0     True           0        0          2017
# 2415   50.0     True           0        0          2017
#
# [3676 rows x 11 columns]

# %% [markdown]
# ### Zero subscribes courses

# %%
df[(df['subscribes'] == 0)]
# Out:
#            id                                              title  \
# 37    1234656                              4 Week Rhythm Mastery
# 44    1231958        60 Minutes to Fundamental Accounting Skills
# 91    1265814  ABRSM Grade III Piano Class - Handel Sonatina ...
# 98    1219820  Accounting - The 6 most important rules you mu...
# 185    872262                Adobe Photoshop pentru Social Media
# ...       ...                                                ...
# 3323   715476        The Cuckoo Strategy to get European Funding
# 3462  1214670                  Tune that Sour Note on Your Piano
# 3507  1251654   Understand Core Finance Principles in 60 Minutes
# 3510  1035638                 Understanding Financial Statements
# 3639  1271430        Workshop on Banking Credit Analysis Process
#
#                   subject           level  duration_minutes  lectures  price  \
# 37    Musical Instruments  Beginner Level             150.0        28   20.0
# 44       Business Finance  Beginner Level             150.0         9   75.0
# 91    Musical Instruments  Beginner Level              31.0         5   20.0
# 98       Business Finance      All Levels              60.0         9   20.0
# 185        Graphic Design  Beginner Level              34.0        12   20.0
# ...                   ...             ...               ...       ...    ...
# 3323     Business Finance      All Levels              60.0         6  160.0
# 3462  Musical Instruments      All Levels              33.0         6   20.0
# 3507     Business Finance  Beginner Level             150.0        13   75.0
# 3510     Business Finance      All Levels              60.0        10   25.0
# 3639     Business Finance      All Levels              90.0         7  100.0
#
#       is_paid  subscribes  reviews  publish_date
# 37       True           0        0          2017
# 44       True           0        0          2017
# 91       True           0        0          2017
# 98       True           0        0          2017
# 185      True           0        0          2016
# ...       ...         ...      ...           ...
# 3323     True           0        0          2016
# 3462     True           0        0          2017
# 3507     True           0        0          2017
# 3510     True           0        0          2016
# 3639     True           0        0          2017
#
# [65 rows x 11 columns]

# %% [markdown]
# ### Show all the courses related to python

# %%
df[df['title'].str.contains('Python')]#.head()
# Out:
#            id                                              title  \
# 216    599504  Advanced Scalable Python Web Development Using...
# 776     47963  Coding for Entrepreneurs: Learn Python, Django...
# 813    631128  Complete Python Web Course: Build 8 Python Web...
# 841    186096  Core: A Web App Reference Guide for Django, Py...
# 1398   394832  Fun and creative web engineering with Python a...
# 1929  1038538            Introduction to QGIS Python Programming
# 1966   902888          Investment Portfolio Analysis with Python
# 2291   391546        Learn Python and Django: Payment Processing
# 2292  1063722            Learn Python Django - A Hands-On Course
# 2338   546848  Learn to code in Python and learn Adobe Photos...
# 2901   368340    Professional Python Web Development Using Flask
# 2903  1035940  Professional RESTful API Design using Python F...
# 2924   270808                      Projects in Django and Python
# 2947  1170894  Python Algo Stock Trading: Automate Your Trading!
# 2948  1070886         Python Algo Trading: FX Trading with Oanda
# 2949  1196544   Python Algo Trading: Sentiment Trading with News
# 2950   822444  Python and Django Full Stack Web Developer Boo...
# 2951   477702  Python for Beginners: Python Programming Langu...
# 2952  1035472  Python for Finance: Investment Fundamentals & ...
# 2953   529828                     Python for Trading & Investing
# 2954    70640  Python Programming: Create an Digital Marketpl...
# 2955   523312                             Python Web Programming
# 2957  1088656          Quantitative Trading Analysis with Python
# 3008   970600                    REST APIs with Flask and Python
# 3149   815482               Stock Technical Analysis with Python
# 3267   938560  The Complete Ethical Hacking Course 2.0: Pytho...
# 3455    76052  Try Django 1.9 | Build a Blog and Learn Python...
# 3567    16646                        Web Programming with Python
# 3568   574082        Web Scraping with Python, Ruby & import. io
#
#                subject               level  duration_minutes  lectures  price  \
# 216    Web Development  Intermediate Level             840.0        71  120.0
# 776    Web Development          All Levels            2700.0       251  195.0
# 813    Web Development          All Levels             960.0       173  110.0
# 841    Web Development          All Levels            1560.0       154  195.0
# 1398   Web Development          All Levels             120.0        25    0.0
# 1929   Web Development      Beginner Level             210.0        28   85.0
# 1966  Business Finance          All Levels             420.0        37   50.0
# 2291   Web Development          All Levels             210.0        23   70.0
# 2292   Web Development      Beginner Level             120.0        18   50.0
# 2338    Graphic Design          All Levels             120.0        29   50.0
# 2901   Web Development      Beginner Level             870.0       102  120.0
# 2903   Web Development  Intermediate Level             270.0        36  120.0
# 2924   Web Development          All Levels             390.0        28   60.0
# 2947  Business Finance      Beginner Level             150.0        41   95.0
# 2948  Business Finance  Intermediate Level             180.0        33  200.0
# 2949  Business Finance          All Levels             420.0        42  200.0
# 2950   Web Development          All Levels            1890.0       191  200.0
# 2951   Web Development      Beginner Level             300.0        84  150.0
# 2952  Business Finance          All Levels             390.0       103  195.0
# 2953  Business Finance          All Levels             300.0        36   95.0
# 2954   Web Development          All Levels            1560.0       161  195.0
# 2955   Web Development      Beginner Level             360.0        60  100.0
# 2957  Business Finance          All Levels             330.0        49   50.0
# 3008   Web Development  Intermediate Level             750.0       115  110.0
# 3149  Business Finance          All Levels             480.0        46   50.0
# 3267   Web Development          All Levels             660.0        66  195.0
# 3455   Web Development          All Levels            1200.0       147   50.0
# 3567   Web Development          All Levels             240.0        53   50.0
# 3568   Web Development          All Levels             270.0        46   75.0
#
#       is_paid  subscribes  reviews  publish_date
# 216      True        1299       56          2016
# 776      True       23412      799          2013
# 813      True        7489      941          2015
# 841      True        2497       98          2014
# 1398    False       10917      319          2015
# 1929     True         197       26          2016
# 1966     True         209       13          2016
# 2291     True       17714      198          2015
# 2292     True        1339       21          2017
# 2338     True        1132        1          2015
# 2901     True        3420      489          2015
# 2903     True         578       25          2017
# 2924     True        1764       53          2014
# 2947     True        1165       21          2017
# 2948     True         453       42          2017
# 2949     True         294       19          2017
# 2950     True       11832     1883          2017
# 2951     True        6153      125          2015
# 2952     True        3811      278          2017
# 2953     True         638       25          2015
# 2954     True        4198      145          2013
# 2955     True        1020       46          2015
# 2957     True         256       17          2017
# 3008     True        5151      737          2016
# 3149     True         409       35          2016
# 3267     True        7827      268          2016
# 3455     True        7407      172          2014
# 3567     True       35267      217          2012
# 3568     True         973       50          2015

# %% [markdown]
# ### Maximum number of subscribers of `subscribers` column for each level of `level` column

# %%
df.groupby('level')['subscribes'].max()
# Out:
# level
# All Levels            268923
# Beginner Level        161029
# Expert Level            5172
# Intermediate Level     29167
# Name: subscribes, dtype: int64

# %% [markdown]
# # Functions to get information from df

# %% [markdown]
# ### Function to get top courses based on user demand

# %%
def get_top_records(df, n, by):
    return df.sort_values(by = by, ascending = False).head(n)

# %%
get_top_records(df, 10, 'price')
# Out:
#            id                                              title  \
# 2182   200598  LEARN HARMONICA, amaze your friends and have f...
# 2687  1122146  Penny Stocks Value & Chart Pattern Trading (2 ...
# 3307   502772  The Complete Value Investing Course: A Proven ...
# 1541  1209556  Hedge Fund Trading Systems Part Two - Stocks &...
# 3311   764164              The Complete Web Developer Course 2.0
# 3314   548278  The Complete Web Development Course -  Build 1...
# 461     22825                             Beginner Guitar Method
# 1540   986272   Hedge Fund Trading Systems For Stocks - Part One
# 454   1042110  Beginner Full Stack Web Development: HTML, CSS...
# 3318    50528  The Complete Wordpress Plugin Development Cour...
#
#                   subject           level  duration_minutes  lectures  price  \
# 2182  Musical Instruments      All Levels             930.0       131  200.0
# 2687     Business Finance  Beginner Level              90.0        31  200.0
# 3307     Business Finance      All Levels             270.0        49  200.0
# 1541     Business Finance    Expert Level             150.0        23  200.0
# 3311      Web Development      All Levels            1830.0       304  200.0
# 3314      Web Development      All Levels            4590.0       384  200.0
# 461   Musical Instruments  Beginner Level             240.0        23  200.0
# 1540     Business Finance      All Levels              90.0        21  200.0
# 454       Web Development  Beginner Level            1530.0       138  200.0
# 3318      Web Development      All Levels             150.0        33  200.0
#
#       is_paid  subscribes  reviews  publish_date
# 2182     True        8857      718          2014
# 2687     True        1033        2          2017
# 3307     True        2146      212          2015
# 1541     True          56       10          2017
# 3311     True      114512    22412          2016
# 3314     True        7501     1213          2015
# 461      True          85        2          2012
# 1540     True          52        8          2016
# 454      True        2687      331          2017
# 3318     True        1215       58          2013

# %%
get_top_records(df, 5, 'subscribes')
# Out:
#           id                                              title  \
# 2227   41295               Learn HTML5 Programming From Scratch
# 775    59014                     Coding for Entrepreneurs Basic
# 3380  625204                         The Web Developer Bootcamp
# 640   173548  Build Your First Website in 1 Week with HTML5 ...
# 3311  764164              The Complete Web Developer Course 2.0
#
#               subject           level  duration_minutes  lectures  price  \
# 2227  Web Development      All Levels             630.0        45    0.0
# 775   Web Development  Beginner Level             210.0        27    0.0
# 3380  Web Development      All Levels            2580.0       342  200.0
# 640   Web Development  Beginner Level             180.0        30    0.0
# 3311  Web Development      All Levels            1830.0       304  200.0
#
#       is_paid  subscribes  reviews  publish_date
# 2227    False      268923     8629          2013
# 775     False      161029      279          2013
# 3380     True      121584    27445          2015
# 640     False      120291     5924          2014
# 3311     True      114512    22412          2016

# %% [markdown]
# ### Search courses based on specific criteria

# %% [markdown]
# **search_course() parameters:**
#
# _`df`_: Dataframe
# _`subject`_ : This parameter indicates the subject of the course you are looking for.
# _`is_paid`_ : whether course is free or paid.  (default value is True)
# _`n`_ : number of rows which you prefer to be return as output.
# _`ascending`_ : results shown in ascending or not.
# _`min_price`_ : minimum price (default is 0).
# _`max_price`_ : minimum price (default is 200).602

# %% [markdown]
# **Possible values for subject parameter:**
# - Web Development
# - Business Finance
# - Musical Instruments
# - Graphic Design

# %%
def search_course(df, subject, sort_by, is_paid = True, n = 20, ascending = False, min_price = 0, max_price = 200):
    return df[(df['subject'] == subject) & (df['is_paid'] == is_paid) & (df['price'] >= min_price) & (df['price'] <= max_price)].sort_values(by = sort_by, ascending = ascending).head(n)

# %%
search_course(df, 'Web Development', 'price', True, 70, 90)
# Out:
#            id                                              title  \
# 2638  1103954  Node.js: The Essentials + API Frameworks Expre...
# 587   1111552  Build a Complete JQuery Plugin (Image Pop-up D...
# 2308   769314         Learn Ruby Programming The Easy Way - Lite
# 591    260444  Build a file hosting/sharing site in less than...
# 2310   929260                Learn SASS: from beginner to expert
# ...       ...                                                ...
# 815   1062686  Complete RESPONSIVE Website Design with HTML5 ...
# 2761   639848  PHP Graphic Techniques: CAPTCHA/ Create a veri...
# 770    158934              Code a personal splash page in 1 hour
# 2884   628876  Practical Web Development: Make Websites Quick...
# 772    629088  Code your first Website using HTML & CSS: Proj...
#
#               subject           level  duration_minutes  lectures  price  \
# 2638  Web Development  Beginner Level              60.0        34   20.0
# 587   Web Development      All Levels              60.0        12   20.0
# 2308  Web Development      All Levels              34.0         7   20.0
# 591   Web Development      All Levels              90.0        13   20.0
# 2310  Web Development  Beginner Level              60.0        13   20.0
# ...               ...             ...               ...       ...    ...
# 815   Web Development  Beginner Level             540.0        97   20.0
# 2761  Web Development      All Levels              43.0        11   20.0
# 770   Web Development  Beginner Level              60.0        10   20.0
# 2884  Web Development      All Levels             120.0        20   20.0
# 772   Web Development  Beginner Level              90.0        16   20.0
#
#       is_paid  subscribes  reviews  publish_date
# 2638     True        2760       52          2017
# 587      True        1126       10          2017
# 2308     True        1186       12          2016
# 591      True         976       29          2014
# 2310     True        1734        9          2016
# ...       ...         ...      ...           ...
# 815      True        2204        6          2017
# 2761     True        8320       73          2015
# 770      True       10610       83          2014
# 2884     True        2389        7          2015
# 772      True        9554      368          2015
#
# [70 rows x 11 columns]

# %%
search_course(df = df, sort_by='subscribes', subject = 'Business Finance')
# Out:
#           id                                              title  \
# 3269  648826         The Complete Financial Analyst Course 2017
# 468   321410  Beginner to Pro in Excel: Financial Modeling a...
# 518   301442       Black Algo Trading: Build Your Trading Robot
# 1344  308690  Forex Trading A-Z™ - With LIVE Examples of For...
# 2406  285638  Learn to Trade for Profit:Trading with Japanes...
# 2680  401784  Options Trading Introduction: Day Trade Stock ...
# 1888  302562  Introduction to Accounting: The Language of Bu...
# 869   116128  CPA 101: How To Master Affiliate Marketing In ...
# 1902  888716  Introduction to Finance, Accounting, Modeling ...
# 2403  325834  Learn to Trade for Profit: Find and Trade Winn...
# 1331  260470  Forex Robots: Expect To Earn 175% P.A. Forex R...
# 1219  109622        Finance - Ratios Analysis & Interpretations
# 879   506568  Create A Business From Home Trading Stocks Tod...
# 2677   43319           Options Trading Basics (3-Course Bundle)
# 99    640100  Accounting & Financial Statement Analysis: Com...
# 3152  165964  Stock Trading Ninja: Complete System For Tradi...
# 3426  192870  Trading Penny Stocks: A Guide for All Levels I...
# 1671  252396  How to Pick The Right Penny Stocks To Invest I...
# 3258  380970  The Complete Bitcoin Course: Get .001 Bitcoin ...
# 3286  965832        The Complete Investment Banking Course 2017
#
#                subject           level  duration_minutes  lectures  price  \
# 3269  Business Finance      All Levels             600.0       174  195.0
# 468   Business Finance      All Levels             450.0       138  195.0
# 518   Business Finance      All Levels             960.0       227  200.0
# 1344  Business Finance  Beginner Level             330.0        52  195.0
# 2406  Business Finance  Beginner Level             180.0        45   60.0
# 2680  Business Finance  Beginner Level             150.0        30   95.0
# 1888  Business Finance  Beginner Level             690.0       134   20.0
# 869   Business Finance      All Levels              90.0        21  100.0
# 1902  Business Finance      All Levels             270.0        61  200.0
# 2403  Business Finance      All Levels             180.0        77   95.0
# 1331  Business Finance      All Levels             330.0        42  200.0
# 1219  Business Finance  Beginner Level             150.0        41   30.0
# 879   Business Finance      All Levels             120.0        16   75.0
# 2677  Business Finance  Beginner Level             660.0        45  180.0
# 99    Business Finance      All Levels             180.0        43  150.0
# 3152  Business Finance      All Levels             270.0        38  155.0
# 3426  Business Finance      All Levels             180.0        25  150.0
# 1671  Business Finance      All Levels             150.0        23  150.0
# 3258  Business Finance      All Levels             390.0        80   45.0
# 3286  Business Finance      All Levels             330.0       110  195.0
#
#       is_paid  subscribes  reviews  publish_date
# 3269     True       24481     2347          2016
# 468      True       22257     2697          2014
# 518      True       20195     1113          2014
# 1344     True       16900     2476          2014
# 2406     True       16385      273          2014
# 2680     True       12394      218          2015
# 1888     True       11958      370          2014
# 869      True       11517       92          2013
# 1902     True       11441     1118          2016
# 2403     True       10605       71          2014
# 1331     True       10603      872          2014
# 1219     True       10338       52          2013
# 879      True       10149       83          2015
# 2677     True       10100      985          2013
# 99       True       10042      594          2015
# 3152     True        9445      497          2014
# 3426     True        9221      138          2014
# 1671     True        9015       65          2014
# 3258     True        8797      449          2015
# 3286     True        8575      809          2016

# %% [markdown]
# # Visualization

# %% [markdown]
# ### Correlation heatmap

# %%
plt.figure(figsize = (20, 7))
sns.heatmap(df.corr(numeric_only=True), annot = True, cmap = 'coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ### Stacked bar plot for subject/level

# %%
level_per_subj = df.groupby(['subject'])['level'].value_counts().to_frame()
level_per_subj
# Out:
#                                         count
# subject             level
# Business Finance    All Levels            696
#                     Beginner Level        340
#                     Intermediate Level    128
#                     Expert Level           31
# Graphic Design      All Levels            298
#                     Beginner Level        242
#                     Intermediate Level     57
#                     Expert Level            5
# Musical Instruments Beginner Level        296
#                     All Levels            276
#                     Intermediate Level    101
#                     Expert Level            7
# Web Development     All Levels            658
#                     Beginner Level        391
#                     Intermediate Level    135
#                     Expert Level           15

# %%
# Reset index to make 'subject' and 'level' as columns
df_reset = level_per_subj.reset_index()

plt.figure(figsize=(12, 8))
sns.barplot(x='count', y='subject', hue='level', data=df_reset, palette='viridis')
plt.title('Count of Courses by Subject and Level', fontsize=20)
plt.xlabel('Count', fontsize=15)
plt.ylabel('Subject', fontsize=15)
plt.legend(title='Level', title_fontsize='12')
plt.show()

# %%
plt.figure(figsize=(18, 12))
df_reset.pivot_table(values='count', index='subject', columns='level', aggfunc='sum').plot(kind='bar', stacked=False, colormap='viridis')
plt.title('Count of Courses by Subject and Level', fontsize=20)
plt.xlabel('Subject', fontsize=15)
plt.ylabel('Count', fontsize=15)
plt.legend(title='Level', title_fontsize='12')
plt.show()

# %% [markdown]
# ### Courses per year

# %%
courses_per_year = df.groupby('publish_date')['publish_date'].agg({'count', 'mean'})
courses_per_year
# Out:
#               count    mean
# publish_date
# 2011              5  2011.0
# 2012             45  2012.0
# 2013            201  2013.0
# 2014            490  2014.0
# 2015           1014  2015.0
# 2016           1204  2016.0
# 2017            717  2017.0

# %%
plt.figure(figsize = (16, 8))
courses_per_year['count'].plot(kind = 'bar')
plt.title("Courses Per Year", fontsize = 20)
plt.xlabel("Year", fontsize = 15)
plt.ylabel("Number Of Courses Per Year", fontsize = 15)
plt.show()

# %% [markdown]
# ### Using boxplot to check outliers

# %%
df.boxplot(figsize = (18, 10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Histogram chart of for each numeric feature of `df`

# %%
def hist_chart(cols):
    for col in cols:
        df[col].plot(kind='hist', bins=100, edgecolor='black', figsize=(12, 6))
        plt.title(f'Distribution of Course {col}')
        plt.xlabel(f'{col}')
        plt.ylabel('Frequency')
        plt.show()

# %%
hist_chart(['duration_minutes', 'lectures', 'price', 'subscribes', 'reviews'])

# %% [markdown]
# ### Distribution of `subject` column

# %%
df['subject'].value_counts().plot(kind='bar', color='black', figsize=(12, 6))
plt.title('Distribution of Subjects')
plt.xlabel('Subject')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Pie chart of `is_paid` column

# %%
plt.figure(figsize = (12, 8))
df['is_paid'].value_counts().plot(kind='pie', autopct='%1.1f%%', colors=['lightcoral', 'lightskyblue'])
plt.title('Distribution of Paid and Free Courses')
plt.ylabel('')
plt.show()

# %% [markdown]
# ### Pairplot for numerical features

# %%
sns.pairplot(df[['duration_minutes', 'lectures', 'price', 'subscribes', 'reviews']])
plt.suptitle('Pairplot of Numeric Variables', y=1.02)
plt.show()
