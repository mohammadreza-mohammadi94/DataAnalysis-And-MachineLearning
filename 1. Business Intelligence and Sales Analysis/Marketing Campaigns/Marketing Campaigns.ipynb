# %% [markdown]
# <div align="center">
#     <a href="https://ibb.co/6cC6vgq"><img src="https://i.ibb.co/204X8gp/how-can-digital-marketing-help-businesses.jpg" alt="how-can-digital-marketing-help-businesses" border="0"></a>
# </div>

# %% [markdown]
# # Table Of Content
# * 1. [Introduction](#1)
#     * 1.1 [Dataset Source](#1.1)
#     * 1.2 [About Marketing](#1.2)
# * 2. [First Organization](#2)
#     * 2.1 [Loading Libraries](#2.1)
#     * 2.2 [Loading Dataset](#2.2)
# * 3. [Exploring Dataset](#3)
#     * 3.1 [Understanding Variables](#3.1)
#     * 3.2 [Initial Exploration](#3.2)
#     * 3.3 [Statistical Summary](#3.3)
#         * 3.3.1 [Analysis Output ](#3.3.1)
# * 4. [Data Cleaning](#4)
#     * 4.1 [Marital Status Variable](#4.1)
#     * 4.2 [Income Variable](#4.2)
#         * 4.2.1 [Missing Values](#4.2.1)
#     * 4.3 [Dt_Customer Variable](#4.3)
# * 5. [Exploratory Data Analysis](#5)
#     * 5.1 [Distributions](#5.1)
#     * 5.2 [Barplot for Categorical Variables](#5.2)
#     * 5.3 [Bi-Variate Analysis By Boxolot](#5.3)
#     * 5.4 [Average Number of Store Purchases by Marital Status](#5.4)
#     * 5.5 [Response Percentange](#5.5)
#     * 5.6 [Age Distribution By Education](#5.6)
#     * 5.7 [Boxplot of Numeric Features](#5.7)
#     * 5.8 [Scatter Plot](#5.8)
#     * 5.9 [Heatmap](#5.9)

# %% [markdown]
# # 1. Introduction <a id=1></a>

# %% [markdown]
# ## 1.1 Dataset Source <a id=1.1></a>

# %% [markdown]
# Explore a comprehensive dataset for marketing campaign data analysis on Kaggle. This dataset includes information on customer demographics, purchase behavior, and responses to various marketing campaigns. Utilize this data to gain insights into customer segmentation, campaign performance, and predictive modeling.
#
# Access the dataset here: [Marketing Campaign Data Analysis](https://www.kaggle.com/code/sahilnbajaj/marketing-campaign-data-analysis)

# %% [markdown]
# ## 1.2 About Marketing <a id=1.2></a>

# %% [markdown]
# ### Marketing and Its Relation with Programming (Especially in Python)
#
# #### Introduction to Marketing in the Digital Age
#
# Marketing has evolved significantly with the advent of digital technologies. In today's data-driven world, marketing involves not only traditional methods but also sophisticated techniques to analyze consumer behavior, predict trends, and personalize experiences. The integration of programming, particularly with languages like Python, has revolutionized marketing strategies and operations.
#
# #### How Programming Enhances Marketing
#
# 1. **Data Analysis and Insights**:
#    - **Data Collection**: Modern marketing relies heavily on data collected from various sources such as social media, websites, customer transactions, and surveys.
#    - **Data Cleaning and Preprocessing**: Programming languages like Python offer powerful libraries (e.g., Pandas, NumPy) to clean and preprocess raw data, making it ready for analysis.
#    - **Data Visualization**: Tools like Matplotlib, Seaborn, and Plotly in Python help marketers visualize data trends and patterns, aiding in better decision-making.
#
# 2. **Predictive Analytics and Machine Learning**:
#    - **Customer Segmentation**: Python's machine learning libraries (e.g., scikit-learn, TensorFlow, Keras) can be used to segment customers based on their behavior, preferences, and demographics.
#    - **Churn Prediction**: By analyzing past customer data, marketers can use Python to build models that predict which customers are likely to churn and take proactive measures to retain them.
#    - **Sales Forecasting**: Time series analysis and forecasting models can predict future sales trends, helping businesses plan their inventory and marketing strategies.
#
# 3. **Personalization and Recommendation Systems**:
#    - **Personalized Marketing**: Python can be used to analyze customer behavior and create personalized marketing messages and offers, increasing engagement and conversion rates.
#    - **Recommendation Engines**: Utilizing collaborative filtering and content-based filtering techniques, Python helps build recommendation systems that suggest products or services to customers based on their past interactions and preferences.
#
# 4. **Automation and Efficiency**:
#    - **Marketing Automation**: Python scripts can automate repetitive marketing tasks such as email campaigns, social media posting, and A/B testing, allowing marketers to focus on strategy and creativity.
#    - **Web Scraping**: Tools like BeautifulSoup and Scrapy allow marketers to gather competitive intelligence and market research by scraping data from websites and social media platforms.
#
# 5. **Natural Language Processing (NLP)**:
#    - **Sentiment Analysis**: Python's NLP libraries (e.g., NLTK, spaCy) can analyze customer reviews and social media mentions to gauge public sentiment towards products or brands.
#    - **Chatbots and Customer Support**: NLP techniques enable the creation of intelligent chatbots that provide real-time customer support and enhance the user experience on websites and apps.
#
# #### Python in Action: Marketing Campaign Analysis
#
# Python's versatility makes it an ideal tool for analyzing marketing campaign data. For instance, the "Marketing Campaign Data Analysis" on Kaggle provides a rich dataset to explore various aspects of customer behavior and campaign performance. Using Python, one can:
#
# - **Load and Explore Data**: Use Pandas to read and inspect the dataset.
# - **Clean and Prepare Data**: Handle missing values, encode categorical variables, and normalize numerical data.
# - **Perform Exploratory Data Analysis (EDA)**: Visualize data distributions and relationships between variables using Seaborn and Matplotlib.
# - **Build Predictive Models**: Create machine learning models to predict campaign success or customer lifetime value using scikit-learn.
# - **Evaluate and Optimize Models**: Assess model performance with metrics like accuracy, precision, and recall, and optimize them using techniques like cross-validation and hyperparameter tuning.
#
#
# Programming, especially in Python, empowers marketers to leverage data for more informed and effective decision-making. From data analysis and predictive modeling to automation and personalization, Python provides the tools needed to enhance marketing strategies and drive business growth. By integrating Python into their workflows, marketers can stay ahead in the competitive landscape and deliver more targeted, efficient, and impactful campaigns.

# %% [markdown]
# # 2. First Organization <a id=2></a>

# %% [markdown]
# ## 2.1 Loading Libraries <a id=2.1></a>

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 2.2 Loading Dataset <a id=2.2></a>

# %%
df = pd.read_csv("marketing_data.csv")
df.head()
# Out:
#       ID  Year_Birth   Education Marital_Status       Income  Kidhome  \
# 0   1826        1970  Graduation       Divorced  $84,835.00         0
# 1      1        1961  Graduation         Single  $57,091.00         0
# 2  10476        1958  Graduation        Married  $67,267.00         0
# 3   1386        1967  Graduation       Together  $32,474.00         1
# 4   5371        1989  Graduation         Single  $21,474.00         1
#
#    Teenhome Dt_Customer  Recency  MntWines  ...  NumStorePurchases  \
# 0         0     6/16/14        0       189  ...                  6
# 1         0     6/15/14        0       464  ...                  7
# 2         1     5/13/14        0       134  ...                  5
# 3         1     5/11/14        0        10  ...                  2
# 4         0      4/8/14        0         6  ...                  2
#
#    NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  \
# ...

# %% [markdown]
# # 3. Expolroing Dataset <a id=3></a>

# %% [markdown]
# ## 3.1 Understanding Variables <a id=3.1></a>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2216 non-null   object
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %% [markdown]
# ID: Unique identifier for each customer.
#
# Year_Birth: Year of birth of the customer.
#
# Education: Education level of the customer. This is a categorical variable which may include values like 'Graduation', 'PhD', 'Master', '2n Cycle', etc.
#
# Marital_Status: Marital status of the customer. This is a categorical variable with values such as 'Single', 'Married', 'Divorced', etc.
#
# Income: Annual income of the customer. Some values might be missing (hence, the slightly lower count).
#
# Kidhome: Number of children in the customer's household.
#
# Teenhome: Number of teenagers in the customer's household.
#
# Dt_Customer: Date when the customer was enrolled in the company's program.
#
# Recency: Number of days since the customer's last purchase.
#
# MntWines: Amount spent on wine in the last 2 years.
#
# MntFruits: Amount spent on fruits in the last 2 years.
#
# MntMeatProducts: Amount spent on meat products in the last 2 years.
#
# MntFishProducts: Amount spent on fish products in the last 2 years.
#
# MntSweetProducts: Amount spent on sweet products in the last 2 years.
#
# MntGoldProds: Amount spent on gold products in the last 2 years.
#
# NumDealsPurchases: Number of purchases made with a discount.
#
# NumWebPurchases: Number of purchases made through the company’s website.
#
# NumCatalogPurchases: Number of purchases made using a catalog.
#
# NumStorePurchases: Number of purchases made directly in stores.
#
# NumWebVisitsMonth: Number of visits to the company’s website in the last month.
#
# AcceptedCmp3: 1 if the customer accepted the offer in the 3rd campaign, 0 otherwise.
#
# AcceptedCmp4: 1 if the customer accepted the offer in the 4th campaign, 0 otherwise.
#
# AcceptedCmp5: 1 if the customer accepted the offer in the 5th campaign, 0 otherwise.
#
# AcceptedCmp1: 1 if the customer accepted the offer in the 1st campaign, 0 otherwise.
#
# AcceptedCmp2: 1 if the customer accepted the offer in the 2nd campaign, 0 otherwise.
#
# Response: 1 if the customer accepted the offer in the last campaign, 0 otherwise.
#
# Complain: 1 if the customer has complained in the last 2 years, 0 otherwise.
#
# Country: Country of residence of the customer.

# %% [markdown]
# ## 3.2 Initial Exploration <a id=3.2></a>

# %%
df.head(2)
# Out:
#      ID  Year_Birth   Education Marital_Status       Income  Kidhome  \
# 0  1826        1970  Graduation       Divorced  $84,835.00         0
# 1     1        1961  Graduation         Single  $57,091.00         0
#
#    Teenhome Dt_Customer  Recency  MntWines  ...  NumStorePurchases  \
# 0         0     6/16/14        0       189  ...                  6
# 1         0     6/15/14        0       464  ...                  7
#
#    NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  \
# 0                  1             0             0             0             0
# 1                  5             0             0             0             0
#
#    AcceptedCmp2  Response  Complain  Country
# 0             0         1         0       SP
# 1             1         1         0       CA
#
# [2 rows x 28 columns]

# %%
df.shape
# Out:
# (2240, 28)

# %%
df.columns
# Out:
# Index(['ID', 'Year_Birth', 'Education', 'Marital_Status', 'Income', 'Kidhome',
#        'Teenhome', 'Dt_Customer', 'Recency', 'MntWines', 'MntFruits',
#        'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1',
#        'AcceptedCmp2', 'Response', 'Complain', 'Country'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# ID                      0
# Year_Birth              0
# Education               0
# Marital_Status          0
# Income                 24
# Kidhome                 0
# Teenhome                0
# Dt_Customer             0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# AcceptedCmp3            0
# AcceptedCmp4            0
# AcceptedCmp5            0
# AcceptedCmp1            0
# AcceptedCmp2            0
# Response                0
# Complain                0
# Country                 0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## 3.3 Statistical Summary <a id=3.3></a>

# %%
df.describe().T
# Out:
#                       count         mean          std     min      25%  \
# ID                   2240.0  5592.159821  3246.662198     0.0  2828.25
# Year_Birth           2240.0  1968.805804    11.984069  1893.0  1959.00
# Kidhome              2240.0     0.444196     0.538398     0.0     0.00
# Teenhome             2240.0     0.506250     0.544538     0.0     0.00
# Recency              2240.0    49.109375    28.962453     0.0    24.00
# MntWines             2240.0   303.935714   336.597393     0.0    23.75
# MntFruits            2240.0    26.302232    39.773434     0.0     1.00
# MntMeatProducts      2240.0   166.950000   225.715373     0.0    16.00
# MntFishProducts      2240.0    37.525446    54.628979     0.0     3.00
# MntSweetProducts     2240.0    27.062946    41.280498     0.0     1.00
# MntGoldProds         2240.0    44.021875    52.167439     0.0     9.00
# NumDealsPurchases    2240.0     2.325000     1.932238     0.0     1.00
# ...

# %% [markdown]
# ## 3.3.1 Analysis Output <a id=3.3.1></a>

# %% [markdown]
# ### Summary Statistics Analysis
#
# 1. **ID**:
#    - Mean: 5592.16, Std: 3246.66
#    - Broad range (0 - 11191), diverse dataset.
#
# 2. **Year_Birth**:
#    - Mean: 1968.81, Std: 11.98
#    - Birth years from 1893 to 1996, median 1970.
#
# 3. **Kidhome & Teenhome**:
#    - Kidhome Mean: 0.44, Teenhome Mean: 0.51
#    - Most households have 0-1 kids/teenagers.
#
# 4. **Recency**:
#    - Mean: 49.11, Std: 28.96
#    - Number of days since last purchase, median 49.
#
# 5. **Spending on Products**:
#    - **Wines**: Mean: 303.94, Std: 336.60
#    - **Fruits**: Mean: 26.30, Std: 39.77
#    - **Meat**: Mean: 166.95, Std: 225.72
#    - **Fish**: Mean: 37.53, Std: 54.63
#    - **Sweets**: Mean: 27.06, Std: 41.28
#    - **Gold**: Mean: 44.02, Std: 52.17
#    - Varied spending patterns, some high spenders.
#
# 6. **Purchases**:
#    - **Deals**: Mean: 2.33, Std: 1.93
#    - **Web**: Mean: 4.08, Std: 2.78
#    - **Catalog**: Mean: 2.66, Std: 2.92
#    - **Store**: Mean: 5.79, Std: 3.25
#    - Median purchases show preference for store over web/catalog.
#
# 7. **Web Visits**:
#    - Mean: 5.32, Std: 2.43
#    - Median web visits per month: 6.
#
# 8. **Campaign Acceptance (AcceptedCmp1-5)**:
#    - Mean: ~0.07 (low acceptance), Std: ~0.26
#    - Majority did not accept campaigns.
#
# ### Analysis
# - **Diverse Dataset**: ID range indicates varied customer base.
# - **Age Distribution**: Mainly born between 1959-1977.
# - **Household Composition**: Mostly no kids or teenagers.
# - **Customer Recency**: Median of 49 days.
# - **Spending Patterns**: Significant variance in spending across product categories.
# - **Purchase Preferences**: Higher in-store purchases than online/catalog.
# - **Web Activity**: Regular web visits, with some high-frequency users.
# - **Campaign Response**: Generally low acceptance rates.

# %% [markdown]
# # 4. Data Cleaning <a id=4></a>

# %% [markdown]
# _There are no problem with `ID`, `Year_Birth` and `Education` variables_

# %% [markdown]
# ## 4.1 Marital Statis Variable <a id=4.1></a>

# %%
df.Marital_Status.value_counts()
# Out:
# Marital_Status
# Married     864
# Together    580
# Single      480
# Divorced    232
# Widow        77
# Alone         3
# YOLO          2
# Absurd        2
# Name: count, dtype: int64

# %% [markdown]
# _"YOLO" and "Absurd" are likely unconventional or erroneous entries for the marital status of individuals."YOLO" stands for "You Only Live Once," a popular phrase often used to express a carefree or adventurous attitude."Absurd" generally means ridiculous or unreasonable.Entries like "YOLO" and "Absurd" are anomalies that can affect data analysis. They should be handled appropriately_

# %%
df.Marital_Status.replace(['YOLO', 'Absurd'], 'Other', inplace=True)

# %%
df.Marital_Status.replace('Alone', 'Married', inplace=True)

# %% [markdown]
# ## 4.2 Income Variable <a id=4.2></a>

# %% [markdown]
# _At first step i prefer to remove "$" symbol and then try to change its dtype to numeric_

# %%
df.Income.value_counts()
# Out:
# Income
# $7,500.00      12
# $35,860.00      4
# $46,098.00      3
# $39,922.00      3
# $67,445.00      3
#                ..
# $46,086.00      1
# $42,243.00      1
# $35,788.00      1
# $36,026.00      1
# $94,871.00      1
# Name: count, Length: 1974, dtype: int64

# %%
df.Income = df.Income.str.replace('$', '').str.replace(',', '')
df.Income = pd.to_numeric(df.Income)

# %% [markdown]
# ### 4.2.1 Missing Values <a id=4.2.1></a>

# %% [markdown]
# _At second step, there few missing values in this variable , we can simply drop them or impute missing values by using imputation techniques_

# %%
# Replace missing values with the mean
mean_income = df['Income'].mean()
df['Income'].fillna(mean_income, inplace=True)

# %% [markdown]
# ## 4.3 Dt_Customer Variable <a id=4.3></a>

# %%
df.Dt_Customer = pd.to_datetime(df.Dt_Customer)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2240 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   datetime64[ns]
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %% [markdown]
# # 5. Exploratory Data Analysis <a id=5></a>

# %% [markdown]
# ## 5.1 Distributions <a id=5.1></a>

# %%
def dist(col, bins='auto'):
    plt.figure(figsize=(8, 5))
    sns.histplot(data=df, x=col, bins=bins, color='darkblue', kde=True)
    plt.title(f"{col} Distribution", fontsize=14)
    plt.xlabel(f"{col}", fontsize=10)
    plt.ylabel("Frequnecy", fontsize=10)
    plt.show()

# %%
dist('Income')

# %%
dist('Year_Birth')

# %%
dist('Recency')

# %%
dist('MntWines')

# %%
dist('MntFruits')

# %%
dist('MntMeatProducts')

# %%
dist('MntFishProducts')

# %%
dist('MntSweetProducts')

# %%
dist('MntGoldProds')

# %%
dist('NumDealsPurchases')

# %%
dist('NumWebPurchases')

# %%
dist('NumCatalogPurchases')

# %%
dist('NumStorePurchases')

# %%
dist('NumWebVisitsMonth')

# %% [markdown]
# ## 5.2 Barplot for Categorical Variables <a id=5.2></a>

# %%
def countplot(col):
    plt.figure(figsize=(8, 5))
    sns.countplot(data=df, x=col, palette='dark')
    plt.title(f"{col} Countplot", fontsize=14)
    plt.xlabel(f"{col}", fontsize=10)
    plt.ylabel("Frequnecy", fontsize=10)
    plt.show()

# %%
countplot("Education")

# %%
countplot('Marital_Status')

# %%
countplot('Country')

# %% [markdown]
# ## 5.3 Bi-Variate Analysis By Boxolot <a id=5.3></a>

# %%
plt.figure(figsize=(8 ,5))
sns.boxplot(x='Education', y='Income', data=df)
plt.xticks(rotation=45)
plt.title('Income Distribution by Education Level')
plt.show()

# %%
plt.figure(figsize=(8 ,5))
sns.boxplot(x='Country', y='Income', data=df)
plt.xticks(rotation=45)
plt.title('Income Distribution by Country')
plt.show()

# %% [markdown]
# ## 5.4 Average Number of Store Purchases by Marital Status <a id=5.4></a>

# %%
plt.figure(figsize=(8, 5))
df.groupby('Marital_Status')['NumStorePurchases'].mean().plot(kind='bar')
plt.xlabel('Marital Status')
plt.ylabel('Average Number of Purchases')
plt.title('Average Number of Store Purchases by Marital Status')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## 5.5 Response Percentange <a id=5.5></a>

# %%
plt.figure(figsize=(6, 6))
df['Response'].value_counts().plot(kind='pie', autopct='%1.1f%%', colors=['skyblue', 'lightgreen'])
plt.title('Response Rate Distribution', fontsize=14)
plt.ylabel('')
plt.legend()
plt.show()

# %% [markdown]
# ## 5.6 Age Distribution By Education <a id=5.6></a>

# %%
plt.figure(figsize=(8, 5))
sns.violinplot(x='Education', y='Year_Birth', data=df)
plt.xlabel('Education Level')
plt.ylabel('Year of Birth')
plt.title('Age Distribution by Education Level')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## 5.7 Boxplot of Numeric Features <a id=5.7></a>

# %%
# List of numeric columns
numeric_columns = df.select_dtypes(include=['int64', 'float64']).columns

# Plotting boxplots for numeric columns
plt.figure(figsize=(15, 15))

# Creating subplots for each numeric feature
for i, col in enumerate(numeric_columns):
    plt.subplot(len(numeric_columns)//3 + 1, 3, i+1)
    sns.boxplot(y=df[col])
    plt.title(col)
    plt.tight_layout()

plt.show()

# %% [markdown]
# ## 5.8 Scatter Plot <a id=5.8></a>

# %%
# Function to plot scatter plots for specific pairs of features
def scatter_plot(df, x_feature, y_feature):
    plt.figure(figsize=(8, 5))
    sns.scatterplot(data=df, x=x_feature, y=y_feature)
    plt.title(f'Scatter Plot of {x_feature} vs {y_feature}')
    plt.xlabel(x_feature)
    plt.ylabel(y_feature)
    plt.show()

# %%
scatter_plot(df, 'Income', 'MntWines')

# %%
scatter_plot(df, 'Income', 'NumCatalogPurchases')

# %%
scatter_plot(df, 'Income', 'NumDealsPurchases')

# %%
scatter_plot(df, 'Income', 'NumWebPurchases')

# %%
scatter_plot(df, 'Income', 'NumStorePurchases')

# %%
scatter_plot(df, 'Income', 'NumWebVisitsMonth')

# %%
scatter_plot(df, 'Year_Birth', 'Income')

# %% [markdown]
# ## 5.9 Correlation Heatmap

# %%
plt.figure(figsize=(18, 12))
sns.heatmap(data=df.corr(numeric_only=True), annot=True, fmt='.2f', cmap='Blues')
# Out:
# <AxesSubplot:>
